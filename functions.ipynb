# %% [markdown]
# ***Reuse any part of code***

# %% [markdown]
# **without arguments**

# %%
n1=10
n2=20
add=n1+n2
print("the addition of {} and {} is {}".format(n1,n2,add))
# Out:
# the addition of 10 and 20 is 30

# %%
def <function_name>():
    # write youe code here

# %%
def addition():
    n1=10
    n2=20
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition()
# Out:
# the addition of 10 and 20 is 30

# %%
 # the output will not display untill unless you call thr function

# %%
addition()
# Out:
# the addition of 10 and 20 is 30

# %%
def PGR():
    print('HELLO')
    print('HOW ARE YOU ')
PGR()
# Out:
# HELLO
# HOW ARE YOU

# %%
def addition():
    print('hello')
    print('im writing function')
addition()
# Out:
# hello
# im writing function

# %%
n1=100

# %%
n2=200

# %%
print(n1+n2)
# Out:
# 30

# %%
def hello_world():
    print('hello good morning')
hello_world()
# Out:
# hello good morning

# %%
# take three number find the average
# wap ask the user enter 3 number
# n1=eval(input())
# n2=eval(input())
#n3=eval(input())
# avg=(n1+n2+n3)/3
# first write normal code
# then implement the function

def avg1():
    num1=eval(input("enter a num1:"))
    num2=eval(input("enter a num2:"))
    num3=eval(input("enter a num3:"))
    avg=(num1+num2+num3)/3
    print("the average 0f {},{} and {} is {}".format(num1,num2,num3,avg))
avg1()
# Out:
# enter a num1:11
# enter a num2:22
# enter a num3:33
# the average 0f 11,22 and 33 is 22.0

# %%
**note**:
    we are not sure, the function is defined correct or worng
    untill unless we call the function

# %%
try:
    num1=eval(input("enter a num1:"))
    num2=eval(input("enter a num2:"))
    num3=eval(input("enter a num3:"))
    avg=(num1+num2+num3)/3
    print("the average 0f {} and {} is {}".format(num1,num2,num3,avg))
except Exeption as e:
    print(e)
# Out:
# enter a num1:12
# enter a num2:22
# enter a num3:33
# the average 0f 12 and 22 is 33

# %%
def avg1():
    try:
        num1=eval(input("enter a num1:"))
        num2=eval(input("enter a num2:"))
        num3=eval(input("enter a num3:"))
        avg=(num1+num2+num3)/3
        print("the average 0f {},{} and {} is {}".format(num1,num2,num3,avg))
except Exception as e:
    print(e)
avg()
# Out:
#   Cell In[33], line 8
#     except Exception as e:
#                           ^
# SyntaxError: expected 'except' or 'finally' block

# %%
#wap ask the user bill amount
#wap ask the user tip amount
# calculate total  bill
def bill():
    try:
        bill_amount=eval(input("enter the bill_amount:"))
        tip_amount=eval(input("enter the tip_amount:"))
        total_bill=bill_amount+tip_amount
        print("the total bill of {} is {}:".format(bill_amount+tip_amount,total_bill))
    except Exception as e:
        print(e)
bill()
# Out:
# enter the bill_amount:2000
# enter the tip_amount:50
# the total bill of 2050 is 2050:

# %%
#wap ask the user get a random number between 1 to 100
#print it is even or odd number
# implement using function


import random
num=random.randint(1,100)
if num%2==0:
    print("{} is an even number".format(num))
else:
    print("{} is an odd number".format(num))
# Out:
# 89 is an odd number

# %%
import random
def even_odd1():
    num=random.randint(1,100)
if num%2==0:
    print("{} is an even number".format(num))
else:
    print("{} is an odd number".format(num))
even_odd1()
# Out:
# 89 is an odd number

# %%
import random
def even_odd1():
    print('we are implenmenting even odd function')
    print("take one number")
    num=random.randint(1,100)
if num%2==0:
    print("the reminder is zero")
    print("{} is an even number".format(num))
else:
    print("the remainder is not equal to zero")
    print("{} is an odd number".format(num))
even_odd1()
# Out:
# the remainder is not equal to zero
# 89 is an odd number
# we are implenmenting even odd function
# take one number

# %%
import random
print('hello')
print("python")
def even_odd1():
    try:
        print('we are implenmenting even odd function')
        print("take one number")
        num=random.randint(1,100)
    if num%2==0:
        print("the reminder is zero")
        print("{} is an even number".format(num))
    else:
        print("the remainder is not equal to zero")
        print("{} is an odd number".format(num))
    except Exception as e:
        print(e)
print("calling function")
even_odd1()
print

# %%
def addition():
    n1=20
    n2=30
    print('addition:',n1+n2)
print("mul function starts")
def mul():
    n1=20
    n2=30
    print("mul:",n1*n2)
    print("mul is done")
print("subtraction function starts")
def sub():
    n1=20
    n2=30
    print("sub:",n1*n2)
    print("sub is done")
print("anything remains")
print("no")
print("then call the function")
sub()
mul()
addition()
# Out:
# mul function starts
# subtraction function starts
# anything remains
# no
# then call the function
# sub: 600
# sub is done
# mul: 600
# mul is done
# addition: 50

# %%
def addition(n1,n2):
    n1=10
    n2=20
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))
addition(10,20)
# Out:
# the addition of 10 and 20 is 30

# %%
def additon11():
    add=n111+n222
    print("the addition11 of {} and {} is {}:".format(n1,n2,add))
addition11(200,300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       2     add=n111+n222
#       3     print("the addition11 of {} and {} is {}:".format(n1,n2,add))
# ----> 4 addition11(200,300)
#
# NameError: name 'addition11' is not defined

# %%
# implementing code is using with arguments
def avg1(num1,num2,num3):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    avg=(num1+num2+num3)/3
    print("the average 0f {},{} and {} is {}".format(num1,num2,num3,avg))
avg1(20,30,40)
# Out:
# num1: 20
# num2: 30
# num3: 40
# the average 0f 20,30 and 40 is 30.0

# %%
v1=num%10
v11=num//10
v11
# Out:
# 1234

# %%
12345%10
# Out:
# 5

# %%
1234%10
# Out:
# 4

# %%
123%10
# Out:
# 3

# %%
print(5,end='')
print(1)
# Out:
# 51

# %%
#first how many userd important variables are theree imside the function
#bill_amt,tip_amt what error will come 
def bill():
    try:
        bill_amount=eval(input("enter the bill_amount:"))
        tip_amount=eval(input("enter the tip_amount:"))
        total_bill=bill_amount+tip_amount
        print("the total bill of {} is {}:".format(bill_amount+tip_amount,total_bill))
    except Exception as e:
        print(e)
bill()
# Out:
# enter the bill_amount:5000
# enter the tip_amount:100
# the total bill of 5100 is 5100:

# %%
#what error will come
#name error: bill_amt not defined
def bill(bill_amt,tip_amt):
    try:
        total_bill=bill_amount+tip_amount
        print("the total bill of {} is {}:".format(bill_amount+tip_amount,total_bill))
    except Exception as e:
        print(e)
bill(bill_amt,tip_amt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       7     except Exception as e:
#       8         print(e)
# ----> 9 bill(bill_amt,tip_amt)
#
# NameError: name 'bill_amt' is not defined

# %%
#wap ask the user enter number
#and find thde square of the number
#m-1: write in normal ways
#m-2: write in function with out arguments
#m-3: write in function with arguments

# %%
number=eval(input("enter a number"))
print("the square of {} is {}:".format(number,number*number))
# Out:
# enter a number12
# the square of 12 is 144:

# %%
def square():
    number=eval(input("enter a number"))
    print("the square of {} is {}:".format(number,number*number))
square()
# Out:
# enter a number22
# the square of 22 is 484:

# %%
def square(number):
    print("the square of {} is {}:".format(number,number*number))
square(7)
# how many varibles are there inside the funvtion:number
# Out:
# the square of is7 is 49:

# %%
#wap ask the user 
#get one random number between 1 to 20
#enter a number
#compare these two numbers
# if both are same: print("you won")
# else:print(lost)

# write a nomal way
# create a function with out arguments
# create a function with  arguments


import random
random_num=random.randint(1,20)
num=eval(input("enter a num enter:"))
if random_num==num:
    print("you won")
else:
    print("lost")
# Out:
# enter a num enter:7
# lost

# %%
import random
def compare():
    random_num=random.randint(1,20)
    num=eval(input("enter a num enter:"))
if random_num==num:
    print("you won")
else:
    print(" you lost because the random number is:",random_num)
compare()
# Out:
#  you lost because the random number is: 13
# enter a num enter:8

# %%
import random
def compare(num):
    random_num=random.randint(1,20)
    num=eval(input("enter a num enter:"))
if random_num==num:
    print("you won")
else:
    print(" you lost because the random number is:",random_num)
compare(eval(input("enter a  number"))) # keyword pass
# Out:
#  you lost because the random number is: 13
# enter a  number10
# enter a num enter:10

# %%
import random
def compare(num):
    random_num=random.randint(1,20)
if random_num==num:
    print("you won")
else:
    print(" you lost because the random number is:",random_num)
compare(10)  #  direct pass
# Out:
#  you lost because the random number is: 13

# %%
import random
def compare(random_num,num):
    if random_num==num:
        print("you won")
    else:
        print(" you lost because the random number is:",random_num)
value_random=random.randint(1,20)
value=eval(input("enter number"))
compare(value_random,value)




# step-1: import random
# step-2: function will defin: not give
# step-3: value_random
# step-4:value will get
# step-5:calling the function======== # step-2:
#                                        print won/loss

value_random=random.randint(1,20)
value=eval(input("enter number"))
import random
def compare(random_num,num):
    if random_num==num:
        print("you won")
    else:
        print(" you lost because the random number is:",random_num)
compare(value_random,value)
# Out:
# enter number15
#  you lost because the random number is: 11
# enter number10
#  you lost because the random number is: 17

# %%
# step-1: import random
# step-2: function will defin: not give
# step-5:calling the function======== # step-2:
#                                        print won/loss
# step-3: value_random
# step-4:value will get                        *** ITS NOT WORKS ***

# %%
from random

# %%
import random
def compare(random_num,num):
    if random_num==num:
        print("you won")
    else:
        print(" you lost because the random number is:",random_num)
compare (random.randint(1,20),
eval(input("enter number")))
# Out:
# enter number8
#  you lost because the random number is: 20

# %%
#wap ask the user enter salary
# ask the user enter tax percentage
# calucalute total tax to pay

# %%
def salary():
    salary=eval(input("enter a salary:"))
    tax_percentage=eval(input("enter a tax_percentage:"))
    print("the amount tax paid:",salary*tax_percentage/100)
salary()
# Out:
# enter a salary:50000
# enter a tax_percentage:10
# the amount tax paid: 5000.0

# %%
def tax_cal(salary,tax_per):
    total_tax=salary*tax_percentage/100
    print("the total tax is:",total_tax)
tax_cal(50000,5)
# Out:
# the total tax is: 10000.0

# %%
def tax_cal(salary,tax_per):
    total_tax=salary*tax_percentage/100
    print("the total tax is:",total_tax)
salary=eval(input("enter a salary:"))
tax_percentage=eval(input("enter a tax_percentage:"))
tax_cal(salary,tax_percentage)
# Out:
# enter a salary:500000
# enter a tax_percentage:10
# the total tax is: 50000.0

# %% [markdown]
# ***default parameter***

# %%
# tax percentage is always=20
# fixed
# default parameters

# %%
def tax_cal(salary,tax_per=20):
    total_tax=salary*tax_percentage/100
    print("the total tax is:",total_tax)         # this is called default 
tax_cal(50000)
# Out:
# the total tax is: 5000.0

# %%
def avg(num1,num2,num3):
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(20,30,40)
# Out:
# the avg is: 30.0

# %%
def avg(num1,num2,num3=50):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(20,30,)
# Out:
# num1: 20
# num2: 30
# num3: 50
# the avg is: 33.333333333333336

# %%
num1,num2,num3=100
print(num1,num2,num3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 num1,num2,num3=100
#       2 print(num1,num2,num3)
#
# TypeError: cannot unpack non-iterable int object

# %%
def avg(num1,num3,num2=500):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(200,300,)
# Out:
# num1: 200
# num2: 500
# num3: 300
# the avg is: 333.3333333333333

# %%
def avg(num1,num2=500,num3):
    print("num1:",num1)
    print("num2:",num2)                   ***non-default argument follows
    print("num3:",num3)
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(200,300,)
# Out:
#   Cell In[64], line 1
#     def avg(num1,num2=500,num3):
#                           ^
# SyntaxError: non-default argument follows default argument

# %%
num1,num2,num3=3000======== valid
num1,num2=500,num3
num1,num2,num3=
num1,num2,num3=

# %%
def avg(num1,num3,num2=500):
    print("num1:",num1)
    print("num2:",num2)
    print("num3:",num3)
    num3=800
    add=(num1+num2+num3)
    avg=add/3
    print("the avg is:",avg)
avg(200,300,600)


# while defining function: num3=50
# while you are calling fun num3=60
#after enter inside the fun num3=800`

# %% [markdown]
# .with out arguments
# .with arguments
# .default arguments

# %% [markdown]
# import random
# random.randint()

# %% [markdown]
# complex()  # not provide: default

# %% [markdown]
# from random import randint
# randint(10,20)

# %% [markdown]
# # function=method

# %%
def sum(a,b):
    print(a*b)
sum(10,20)
# Out:
# 200

# %%
# wap ask the user to find area of circle
# basic method 
# withoout arguments
# with arguments
# default argumrnts

# %%
import math

# %%
import math
def area_of_circle(r):
    pi=math.pi
    area1=round(pi*r*r,2)
    print("the area of circle is:",area1)
r=eval(input("enter radius"))
area_of_circle(r)

# import math
# define fun
# getting the r value
# call the fun
# indisde the fun getting the value
#                            area1
#                            print
# Out:
# enter radius20
# the area of circle is: 1256.64

# %%
import math
def area_of_circle(r):
    pi=math.pi
    area1=round(pi*r*r,2)
    print("the area of circle is:",area1)
area_of_circle(eval(input("enter radius")))
# Out:
# enter radius20
# the area of circle is: 1256.64

# %%
import math
def area_of_circle(pii,r=20):
    area1=round(pii*r*r,2)
    print("the area of is:",area1)
pii=math.pi
area_of_circle(pii)
# Out:
# the area of is: 1256.64

# %%
 import math
def area_of_circle():
    pii=math.pi
    r=eval(input("enter the radius"))
    area11=round(pii*r*r,2)
    print("the area of circle is:",area11)
area_of_circle()
# Out:
# enter the radius20
# the area of circle is: 1256.64

# %% [markdown]
# ***return the values***

# %%
 import math
def area_of_circle():
    pii=math.pi
    r=eval(input("enter the radius"))
    area11=round(pii*r*r,2)
    print("the area of circle is:",area11)
    return(area11,pii)

# %%
Area,Pii=area_of_circle()  # 


# area_of_circle() will return tow values
# area11,pii
# area will store in a variable:Area
# pii will store in a varibles
# Out:
# enter the radius20
# the area of circle is: 1256.64

# %%
pii=
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pii()
#
# TypeError: 'float' object is not callable

# %%
import math
def area_of_circle():
    pii=math.pi
    r=eval(input("enter the radius"))
    area11=round(pii*r*r,2)
    print("the area of circle is:",area11)
    return(area11,pii)
Area,pi=area_of_circle()
print(Area)
print(pii)
# Out:
# enter the radius12
# the area of circle is: 452.39
# 452.39
# 3.141592653589793

# %%
# ask the user enter 3 number
#find the sum and average
# return the average value and sum both

# %%
def sum_avg():
    num1=eval(input("enter a num1:"))
    num2=eval(input("enter a num2:"))
    num3=eval(input("enter a num3:"))
    sum=num1+num2+num3
    avg=sum/3
    print("sum:",sum)
    print("avg:",avg)
    return(sum,avg)
sum_avg()
# Out:
# enter a num1:50
# enter a num2:100
# enter a num3:150
# sum: 300
# avg: 100.0
# (300, 100.0)

# %%
def sum_avg(n1,n2,n3):
    sum=(n1+n2+n3)
    avg=sum/3
    print("sum:",sum)
    print("avg:",avg)
    return(sum,avg)
addition,avg=sum_avg(20,30,40)

# sum_avg(),is returing two values
# sum and avg
# sum we are saving in a varible:addition
# sum we are saving in a varible: average
print("addition is:","average is:",avg)
# Out:
# sum: 90
# avg: 30.0
# addition is: average is: 30.0

# %%
# find the biggest number of 3 number
# take and  3 number
# and find the biggest  number
# and return that number

# %%
def biggest_num():
    num1=eval(input("enter a num1:"))
    num2=eval(input("enter a num2:"))
    num3=eval(input("enter a num3:"))
    if num1>num2 and num1>num3:
        print("num1 is greater num")
        return(mun1)
    elif num2>num3:
        print("num2 is greater num")
        return(num2)
    else:
        print("num3 is greater num")
        return(num3)
biggest_num()
# Out:
# enter a num1:60
# enter a num2:80
# enter a num3:90
# num3 is greater num
# 90

# %%
def add(a,b):
    return(a+b)
def sub(a,b):
    return(a-b)
def mul(a,b):
    return(a*b)
def div(a,b):
    return(a/b)
10
# Out:
# 80 -20 1500 0.6

# %%
def aggregation(a,b):
    return(a+b,a-b,a*b,a/b)
add,sub,mul,div=aggregation(30,50)
print(add,sub,mul,round(div,2))
# Out:
# 80 -20 1500 0.6

# %%
def aggregation(a,b):
    return(a+b,a-b,a*b,a/b)
value=aggregation(30,50)
value
# Out:
# (80, -20, 1500, 0.6)

# %%
def add(a,b):return(a+b)
def sub(a,b):return(a-b)
def mul(a,b):return(a*b)
def div(a,b):return(a/b)
val_add=add(20,30)
val_sub=sub(20,30)
val_mul=mul(20,30)
val_div=div(20,30)
print(val_add,val_sub,val_mul,round(val_div,2))
# Out:
# 50 -10 600 0.67

# %% [markdown]
# *local varibles*

# %%
def addition():
    n1=10
    n2=20
    add=n1+n2
    print("the addition of {} and {} is {}:".formate(n1,n2,add))

# %% [markdown]
# ** local varibles**
#  the varibles provided inside the function
# ** global varibles**
#    the varibles provided inside the function

# %%
n1=10
n2=20
def addition():  # no need to provide inside brackers
    # no need to provide
    add=n1+n2
    print("the addition of {} and {} is {}:".formate(n1,n2,add))
addition()

# %%
# inside the function (local variables)
def avg():
    num1=20
    num2=30
    num3=40
    avg=(num1+num2+num3)/3
    print("the average of {},{},and {} is {}".format(num1,num2,num3,avg))
    return(num1,num2)
    avg()
# Out:
# the average of 20,30,and 40 is 30.0

# %%
# outside the function (global varibles)
num1=20
num2=30
num3=40
def avg():
    avg=(num1+num2+num3)/3
    print("the average of {},{},and {} is {}".format(num1,num2,num3,avg))
val1,val2=avg()
# Out:
# the average of 20,30,and 40 is 30.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       6     avg=(num1+num2+num3)/3
#       7     print("the average of {},{},and {} is {}".format(num1,num2,num3,avg))
# ----> 8 val1,val2=avg()
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
.local varibles

# %%
num111=20
num222=30
num333=40
def avg():
    avg=(num111+num222+num333)/3
    print("the average of {},{},and {} is {}".format(num111,num222,num333,avg))
avg()
print(num111*num222)
# Out:
# the average of 20,30,and 40 is 30.0
# 600

# %%
n1=10
n2=20
def addition():
    num1=100
    num2=200
    add=n1+n2
    print("the addition of {} and {} is {}:".format(n1,n2,add))
addition()
print(n1)
# Out:
# the addition of 10 and 20 is 30:
# 10

# %%
n1=10
n2=20
def addition(n1):
    num2=200
    add=n1+n2
    print("the addition of {} and {} is {}:".format(n1,n2,add))
addition(500)
print(n1)
# Out:
# the addition of 500 and 20 is 520:
# 10

# %%
n1=10
n2=20
def addition(n1=700):
    num2=200
    add=n1+n2
    print("the addition of {} and {} is {}:".format(n1,n2,add))
addition(500)
print(n1)


# step1 n1=10
# step2:n2=20
# step3:fun defined n1:200
# step4: calling f`
# Out:
# the addition of 500 and 20 is 520:
# 10

# %%
n1=143
n2=200
def addition(n1=900):
    num2=700
    add=n1+n2
    print("the addition of {} and {} is {}:".format(n1,n2,add))
addition(600)
print(n1)
# Out:
# the addition of 600 and 200 is 800:
# 143

# %%
def addition():
    num1=600
    num2=700
    add=n1+n2
    print("the addition of {} and {} is {}:".format(n1,n2,add))
addition()
# Out:
# the addition of 143 and 200 is 343:

# %%
# we can not use local variable value outside the funtion
# untill unless with out return statement
# i want see local variable outside the funtion,with out using return statement

# %%
global

# %%
n1=10
def update():
    n1=n1+100
    print("n1 value inside funtion is:",n1)
updated()
print(n1)
   
    
# with out return n1,we need to get the updated value
# we need to use local variable outside the function,with out return

# %%
def value():
    global number1
    number1=10
    print(number1)
value()
print(number1)
# Out:
# 10
# 10

# %%
def value():
    number1=10
    print(number1)
value()
# Out:
# 10

# %%
def value():
    global number1,number2
    number1=10                              # it is very important for interviews qus
    number2=50
    print(number1)
value()
print(number1)
print(number2)
# Out:
# 10
# 10
# 50

# %%
n_=10
def update():
    n_=100
    n_=n_+100
    print("n1 value inside funtion is:",n_)
update()  # 110
print(n_) # 200
# Out:
# n1 value inside funtion is: 200
# 10

# %%
n_=10
def update():
    global n_
    n_=100
    n_=n_+100
    print("n1 value inside funtion is:",n_)
update()  # 110
print(n_) # 200
# Out:
# n1 value inside funtion is: 200
# 200

# %%
n1=20
n2=30
def addition(n1):
    num2=700
    add=n1+n2
    print("the addition of {} and {} is {}:".format(n1,n2,add))
addition(600)
print(n2)      # i need to get n2 value 300,instead of 3
print(addition)
# Out:
# the addition of 600 and 30 is 630:
# 30
# <function addition at 0x000001F8306960C0>

# %% [markdown]
# ** function in function***

# %%
def greet():
    print("hello")
    
def name():
    print('python')
greet()
name()
# Out:
# hello
# python

# %%
def greet():
    print("hello")
def name():
    print('python')
    greet()
name()
# step1: define greet()
# step2: define name()
# step3: calling name()
# step4: python
# step5: calling grret()
# step6: hello
# Out:
# python
# hello

# %%
def greet():
    print("hello")
    name()
def name():
    print('python')
greet()
# Out:
# hello
# python

# %%
def greet():
    print("hello")
    name()
def name():
    print('python')
    greet()
greet()
name()
# Out:
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# ...

# %%
def greet():
    print("hello")
    name()
def name():
    print('python')
    greet()
greet()
name()
def greet():
    print("hello")
def name():
    print('python')
    print("how to you do")
greet()
name()





def greet():
    print("hello")
hello
python
hello
python
def name():
    print('python')
    greet()
name()



def greet():
    print("hello")
    name()
def name():
    print('python')
greet()

# %%
print(3)

def fun1():
    print('hello')
    print('python')
print('10+10')
def fun2():
    print('3+5')
    print(3+5)
    fun1()
    print('good')
print(10+10)
def fun3():
    fun1()
    fun2()
fun3()
# Out:
# 3
# 10+10
# 20
# hello
# python
# 3+5
# 8
# hello
# python
# good

# %%
int()
# Out:
# 0

# %%
str()
# Out:
# ''

# %%
# create 4 functions
# def add(a+b)
# print(a+b)
# mul
# div
# sub
# you need to provide some print statements
# if you want enter 1: addition operation will come
# if you want enter 2: mul
# if you want enter 3: div
# if you want enter 4: sub
# operation=input("enter a number")
# a=eval(input())
# b=eval(input())
# if operation=='1':
# add(a,b)
# if operation=='2':
# mul(a,b)
# if operation=='3':
# div(a,b)
# if operation=='4':
# sub(a,b)

# %%
def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):
    print(a*b)
def div(a,b):
    print(a/b)
def main():
    num=eval(input("enter a number:"))
    a=eval(input("enter a num1"))
    b=eval(input("enter a num2"))
    if num==1:
        add(a,b)
    elif num==2:
        sub(a,b)
    elif num==3:
        mul(a,b)
    else:
        div(a,b)
main()
# Out:
# enter a number:11
# enter a num122
# enter a num233
# 0.6666666666666666
